# %% [markdown]
# <a href="https://colab.research.google.com/github/geekynadir/semester-8/blob/main/Week8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("housing.csv")

df = df.rename(columns={
    "longitude": "long",
    "latitude": "lat",
    "housing_median_age": "age",
    "median_house_value": "price"
})

print(df.dtypes)

df["age"] = df["age"].astype(int)
df["price"] = df["price"].astype(float)

df["total_bedrooms"] = pd.to_numeric(df["total_bedrooms"], errors="coerce")
print(df.head())
print(df.dtypes)

# %%
import pandas as pd

df = pd.read_csv("housing.csv")
df_clean = df.dropna()

df_filtered = df[df["housing_median_age"] > 50]
df_filtered2 = df[df["housing_median_age"] < 50]

df_multi = df[(df["housing_median_age"] > 30) & (df["median_income"] > 5)]
df_columns = df[["longitude", "latitude", "median_house_value"]]

df_final = df[df["median_income"] > 5][["longitude", "latitude", "median_house_value"]]

print(df_final.head())
