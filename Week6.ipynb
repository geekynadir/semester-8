# %% [markdown]
# <a href="https://colab.research.google.com/github/geekynadir/semester-8/blob/main/Week6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
arr = [random.randint(1, 100) for _ in range(10)]

print("Array:", arr)
maximum = max(arr)
minimum = min(arr)

print("Maximum value:", maximum)
print("Minimum value:", minimum)
# Out:
# Array: [74, 97, 26, 6, 97, 20, 43, 10, 48, 87]
# Maximum value: 97
# Minimum value: 6

# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5, 6])
matrix = arr.reshape(2, 3)

print(matrix)
# Out:
# [[1 2 3]
#  [4 5 6]]
